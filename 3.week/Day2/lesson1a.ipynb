# %%
import pandas as pd
df = pd.read_csv("data/supermarket_data.csv")
df
# Out:
#        Invoice ID     city customertype  gender                 product  \
# 0     750-67-8428  Nairobi       Member  Female       Health and beauty
# 1     226-31-3081   Nakuru       Normal  Female  Electronic accessories
# 2     631-41-3108  Nairobi       Normal  Female      Home and lifestyle
# 3     123-19-1176  Nairobi       Member  Female       Health and beauty
# 4     373-73-7910  Nairobi       Normal  Female       Health and beauty
# ...           ...      ...          ...     ...                     ...
# 996   233-67-5758   Nakuru       Normal    Male       Health and beauty
# 997   303-96-2227  Mombasa       Normal  Female      Home and lifestyle
# 998   727-02-1313  Nairobi       Member    Male      Food and beverages
# 999   347-56-2442  Nairobi       Normal    Male      Home and lifestyle
# 1000  849-09-3807  Nairobi       Member  Female     Fashion accessories
#
#       itemprice  quantity      total       date   time      payment  \
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assume df is already loaded with sales data
df["date"] = pd.to_datetime(df["date"])
df["month"] = df["date"].dt.month_name()

# Total sales by city
sales_city = df.groupby("city")["total"].sum()

# Average rating by gender
rating_gender = df.groupby("gender")["rating"].mean()

plt.figure(figsize=(12,5))

# Subplot 1: Bar chart (sales by city)
plt.subplot(1,2,1)
sales_city.plot(kind="bar", color="teal")
plt.title("🏙️ Total Sales by City")
plt.ylabel("Total Sales")

# Subplot 2: Bar chart (ratings by gender)
plt.subplot(1,2,2)
rating_gender.plot(kind="bar", color="coral")
plt.title("👩‍🦱👨 Average Rating by Gender")
plt.ylabel("Rating")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_63316/2457173578.py:28: UserWarning: Glyph 127961 (\N{CITYSCAPE}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_63316/2457173578.py:28: UserWarning: Glyph 128105 (\N{WOMAN}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_63316/2457173578.py:28: UserWarning: Glyph 129457 (\N{EMOJI COMPONENT CURLY HAIR}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_63316/2457173578.py:28: UserWarning: Glyph 128104 (\N{MAN}) missing from current font.
#   plt.tight_layout()
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127961 (\N{CITYSCAPE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128105 (\N{WOMAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt

# Sales by payment method per city
sales_payment_city = df.groupby(["city","payment"])["total"].sum().unstack()

plt.figure(figsize=(8,6))
sales_payment_city.plot(kind="bar", stacked=True, colormap="viridis")

plt.title("💳 Sales by Payment Method Across Cities", fontsize=14, fontweight="bold")
plt.xlabel("City", fontsize=12)
plt.ylabel("Total Sales", fontsize=12)
plt.legend(title="Payment Method")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_63316/382635363.py:14: UserWarning: Glyph 128179 (\N{CREDIT CARD}) missing from current font.
#   plt.tight_layout()
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128179 (\N{CREDIT CARD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert date column to datetime
df["date"] = pd.to_datetime(df["date"])
df["month"] = df["date"].dt.month_name()

# Group sales by month
sales_month = df.groupby("month")["total"].sum()

# Group sales by city
sales_city = df.groupby("city")["total"].sum()

plt.figure(figsize=(12,5))

# Subplot 1: Line chart
plt.subplot(1,2,1)
sales_month.plot(kind="line", marker="o", color="royalblue")
plt.title("📈 Sales Trend per Month")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.grid(alpha=0.3)

# Subplot 2: Bar chart
plt.subplot(1,2,2)
sales_city.plot(kind="bar", color="orange")
plt.title("🏙️ Total Sales by City")
plt.ylabel("Total Sales")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_63316/4268896841.py:30: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_63316/4268896841.py:30: UserWarning: Glyph 127961 (\N{CITYSCAPE}) missing from current font.
#   plt.tight_layout()
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127961 (\N{CITYSCAPE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert date column to datetime
df["date"] = pd.to_datetime(df["date"])
df["month"] = df["date"].dt.month_name()

# Group sales by month
sales_month = df.groupby("month")["total"].sum()

# Plot bar chart
plt.figure(figsize=(8,5))
sales_month.plot(kind="bar", color="skyblue", alpha=0.7, label="Bar (Total Sales)")

# Overlay line chart
sales_month.plot(kind="line", marker="o", color="red", label="Line (Trend)")

plt.title("📊 Sales per Month (Bar + Line Overlay)")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
